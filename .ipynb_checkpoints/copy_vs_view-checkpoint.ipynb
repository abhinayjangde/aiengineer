# %%
import numpy as np

# %%
# list copy
nums = [1,2,3,4,5]

sub_list = nums[1:3]
nums[0] =300
print(sub_list)
print(nums)
# Out:
# [2, 3]
# [300, 2, 3, 4, 5]

# %%
# numpy view

arr = np.array([1,2,3,4,5])
sub_arr = arr[1:3]

sub_arr[1] = 90
print(arr)
print(sub_arr)
# Out:
# [ 1 90  3  4  5]
# [90  3]
