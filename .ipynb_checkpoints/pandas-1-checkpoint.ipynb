# %%
import numpy as np
import pandas as pd

# %%
info = {
    "Name" : ["Arya", "Abhi", "Chikoo"],
    "CGPA" : [9.5, 8.4, 9.1]
}

df = pd.DataFrame(info)
# print(df)
# Out:
#      Name  CGPA
# 0    Arya   9.5
# 1    Abhi   8.4
# 2  Chikoo   9.1

# %%
df
# Out:
#      Name  CGPA
# 0    Arya   9.5
# 1    Abhi   8.4
# 2  Chikoo   9.1
